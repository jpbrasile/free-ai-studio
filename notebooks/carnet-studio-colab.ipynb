# %% [markdown]
# # Free AI Studio
#
# Ce carnet est ouvert par le Studio, déjà réglé sur une carte graphique (GPU T4 gratuite, si Colab en donne une).
#
# Acceptez la boîte « Connect to a local Colab MCP server », puis gardez cet onglet ouvert : le Studio y ajoute ses cellules sous vos yeux, les lance, puis les retire.
